# %%
# Basic imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import time as t
import os, glob

# Own code imports
import universal_approximant as ua

# %% [markdown]
# We define some useful functions

# %%
def simple_sinusodial_function(x):
    return ( (1 + np.cos(x + np.pi) ) / 2 )

def tanh(x):
    return ( (1 + np.tanh(x) ) / 2 )

def relu(x):
    return np.clip(x, 0, np.max(x))

# %% [markdown]
# Here we initialize the class and we set the important stuff: relu & 2 layers.
#
# Then, we perform our sweep

# %%
# Define the x domain
x = np.linspace( -1,1,num=41 )
# Define some necessary experimental features
exp_features = {
    "reset": {
        "isEnabled" : True,
        "qub_ampl": 5e-3,
        "cav_ampl": .200
    },
    "drag": {
        "isEnabled" : True,
        "drag_scaling": -523.19163e-12
    }
}

n_layers_range = [1,2,3,4,5]
functions_range = [relu, tanh]
cal_rate_range = [0,10,25,50,100]

for function in functions_range:
    if function == relu: 
        function_name = "relu"
    else:
        function_name = "tanh"

    for n_layers in n_layers_range:
        n_param = 3*n_layers - 1
        # Introduce initial parameters if wanted
        p = np.zeros(n_param)

        for cal_rate in cal_rate_range:
            # Create the Universal Approximant class
            univ_app = ua.UniversalApproximant( ua.EXPERIMENT, n_layers, exp_features )

            # Prepare Universal Approximant class
            univ_app.update_param(p)
            univ_app.define_range(x)
            univ_app.define_function(function)
            univ_app.define_cal_rate(cal_rate)

            time_start = t.perf_counter()

            print("                 ")
            print("                 ")
            print("                 ")
            print("For function: ", function_name)
            print("For number of layers: ", n_layers)
            print("For cal_rate: ", cal_rate)
            print("                 ")

            # Mimimize!
            results = minimize(univ_app.chi_square, p, method='Powell', options={"disp": True})

            time_elapsed = (t.perf_counter() - time_start)
            print("\"time\": ", time_elapsed,",")
            print("\"fun\": ", results.fun,",")
            print("\"message\": \"", results.message,"\",")
            print("\"nfev\": ", results.nfev,",")
            print("\"nit\":", results.nit,",")
            print("\"success\":", results.success,",")
            print("\"x\":", results.x)
# Out:
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  1
# For cal_rate:  0
#
# Optimization terminated successfully.
#          Current function value: 0.089176
#          Iterations: 3
#          Function evaluations: 94
# "time":  1735.8710741999998 ,
# "fun":  0.08917601408646524 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  94 ,
# "nit": 3 ,
# "success": True ,
# "x": [-1.76169693  3.40563407]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  1
# For cal_rate:  10
#
# Optimization terminated successfully.
#          Current function value: 0.090005
#          Iterations: 1
#          Function evaluations: 29
# "time":  585.0613653 ,
# "fun":  0.09000512922228653 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  29 ,
# "nit": 1 ,
# "success": True ,
# "x": [ 0.381966   -1.23606797]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  1
# For cal_rate:  25
#
# Optimization terminated successfully.
#          Current function value: 0.087843
#          Iterations: 2
#          Function evaluations: 54
# "time":  1063.9509689000001 ,
# "fun":  0.08784308613064552 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  54 ,
# "nit": 2 ,
# "success": True ,
# "x": [-0.00585603  0.35349784]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  1
# For cal_rate:  50
#
# Optimization terminated successfully.
#          Current function value: 0.087386
#          Iterations: 4
#          Function evaluations: 138
# "time":  2725.7664460000005 ,
# "fun":  0.0873857191934152 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  138 ,
# "nit": 4 ,
# "success": True ,
# "x": [ 1.24501045 -2.65069006]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  1
# For cal_rate:  100
#
# Optimization terminated successfully.
#          Current function value: 0.089807
#          Iterations: 3
#          Function evaluations: 92
# "time":  1834.9418679 ,
# "fun":  0.08980740876160537 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  92 ,
# "nit": 3 ,
# "success": True ,
# "x": [13.90231884 17.57394267]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  2
# For cal_rate:  0
#
# Optimization terminated successfully.
#          Current function value: 0.088420
#          Iterations: 4
#          Function evaluations: 274
# "time":  5697.056046900001 ,
# "fun":  0.08841996652239661 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  274 ,
# "nit": 4 ,
# "success": True ,
# "x": [ 1.60621002 -2.89127961  3.0722055   1.66853237  8.37486618]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  2
# For cal_rate:  10
#
# Optimization terminated successfully.
#          Current function value: 0.079963
#          Iterations: 4
#          Function evaluations: 290
# "time":  7020.158672899999 ,
# "fun":  0.07996272201351375 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  290 ,
# "nit": 4 ,
# "success": True ,
# "x": [ 17.82678852 -14.65319687   3.12224927  -1.9236566    0.34325434]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  2
# For cal_rate:  25
#
# Optimization terminated successfully.
#          Current function value: 0.086967
#          Iterations: 3
#          Function evaluations: 202
# "time":  4905.697102599999 ,
# "fun":  0.08696658759044337 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  202 ,
# "nit": 3 ,
# "success": True ,
# "x": [-3.00698289  0.81475729 -2.98101334  4.66739387 -1.56103474]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  2
# For cal_rate:  50
#
# Optimization terminated successfully.
#          Current function value: 0.088006
#          Iterations: 2
#          Function evaluations: 138
# "time":  3395.6398160000026 ,
# "fun":  0.08800576468375362 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  138 ,
# "nit": 2 ,
# "success": True ,
# "x": [-1.36494773  0.1593689   1.62808227  7.15390599 -2.06912073]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  2
# For cal_rate:  100
#
# Optimization terminated successfully.
#          Current function value: 0.089084
#          Iterations: 2
#          Function evaluations: 202
# "time":  5156.127633199998 ,
# "fun":  0.08908401245427214 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  202 ,
# "nit": 2 ,
# "success": True ,
# "x": [ 4.66868589 -8.65113501 -6.73141187  0.80299375  0.04434456]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  3
# For cal_rate:  0
#
# Optimization terminated successfully.
#          Current function value: 0.088502
#          Iterations: 3
#          Function evaluations: 348
# "time":  9284.128623999997 ,
# "fun":  0.08850213019593431 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  348 ,
# "nit": 3 ,
# "success": True ,
# "x": [ 0.06428087  2.73170438 -1.30224958  5.80459669 -1.11554324  2.60474909
#   4.253427   -0.14998507]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  3
# For cal_rate:  10
#
# Optimization terminated successfully.
#          Current function value: 0.087498
#          Iterations: 4
#          Function evaluations: 516
# "time":  16015.549153200001 ,
# "fun":  0.08749794665078807 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  516 ,
# "nit": 4 ,
# "success": True ,
# "x": [ 3.5623059   3.7713679   1.06971751 -2.06055259  7.48625849  7.48497819
#  14.20742619 -0.54124097]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  3
# For cal_rate:  25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f40ce3399711> in <module>
#      50
#      51             # Mimimize!
# ---> 52             results = minimize(univ_app.chi_square, p, method='Powell', options={"disp": True})
#      53
#      54             time_elapsed = (t.perf_counter() - time_start)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     588         return _minimize_neldermead(fun, x0, args, callback, **options)
#     589     elif meth == 'powell':
# --> 590         return _minimize_powell(fun, x0, args, callback, **options)
#     591     elif meth == 'cg':
#     592         return _minimize_cg(fun, x0, args, jac, callback, **options)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in _minimize_powell(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    2610             fx2 = fval
#    2611             fval, x, direc1 = _linesearch_powell(func, x, direc1,
# -> 2612                                                  tol=xtol * 100)
#    2613             if (fx2 - fval) > delta:
#    2614                 delta = fx2 - fval
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in _linesearch_powell(func, p, xi, tol)
#    2396     def myfunc(alpha):
#    2397         return func(p + alpha*xi)
# -> 2398     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2399     xi = alpha_min*xi
#    2400     return squeeze(fret), p + xi, xi
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in brent(func, args, brack, tol, full_output, maxiter)
#    2107     options = {'xtol': tol,
#    2108                'maxiter': maxiter}
# -> 2109     res = _minimize_scalar_brent(func, brack, args, **options)
#    2110     if full_output:
#    2111         return res['x'], res['fun'], res['nit'], res['nfev']
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in _minimize_scalar_brent(func, brack, args, xtol, maxiter, **unknown_options)
#    2139                   full_output=True, maxiter=maxiter)
#    2140     brent.set_bracket(brack)
# -> 2141     brent.optimize()
#    2142     x, fval, nit, nfev = brent.get_result(full_output=True)
#    2143     return OptimizeResult(fun=fval, x=x, nit=nit, nfev=nfev,
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in optimize(self)
#    1923         # set up for optimization
#    1924         func = self.func
# -> 1925         xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#    1926         _mintol = self._mintol
#    1927         _cg = self._cg
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in get_bracket_info(self)
#    1897         ### carefully DOCUMENT any CHANGES in core ##
#    1898         if brack is None:
# -> 1899             xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#    1900         elif len(brack) == 2:
#    1901             xa, xb, xc, fa, fb, fc, funcalls = bracket(func, xa=brack[0],
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in bracket(func, xa, xb, args, grow_limit, maxiter)
#    2323     _verysmall_num = 1e-21
#    2324     fa = func(*(xa,) + args)
# -> 2325     fb = func(*(xb,) + args)
#    2326     if (fa < fb):                      # Switch so fa > fb
#    2327         xa, xb = xb, xa
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in myfunc(alpha)
#    2395     """
#    2396     def myfunc(alpha):
# -> 2397         return func(p + alpha*xi)
#    2398     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2399     xi = alpha_min*xi
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# c:\Users\Quantum\Labber\Scripts\Universal Approximant\Universal-Approximator\scenario\universal_approximant.py in chi_square(self, p)
#     222         self.update_param(p)
#     223         P_1 = []
# --> 224         P_0 = self.run()
#     225         P_1 = [1 - x for x in P_0 ]
#     226         result = ( 0.5 / len(self.x) ) * np.sum( ( P_1 - self._fx )**2 )
#
# c:\Users\Quantum\Labber\Scripts\Universal Approximant\Universal-Approximator\scenario\universal_approximant.py in run(self)
#     158                 os.path.join( _RELPATH, "algorithm.labber"), # Here we should write the name parametrically
#     159                 os.path.join( _RELPATH, "res.hdf5" ) )
# --> 160         algorithm_raw = self.alg_meas.performMeasurement()
#     161         result = self._convert_result(algorithm_raw[1])
#     162         return result
#
# C:\Program Files\Labber\Script\Labber\_include37\_ScriptTools.pyc in performMeasurement(self, return_data)
#
# ~\AppData\Local\Programs\Python\Python37\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     393
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#     397
#
# ~\AppData\Local\Programs\Python\Python37\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     472     with Popen(*popenargs, **kwargs) as process:
#     473         try:
# --> 474             stdout, stderr = process.communicate(input, timeout=timeout)
#     475         except TimeoutExpired:
#     476             process.kill()
#
# ~\AppData\Local\Programs\Python\Python37\lib\subprocess.py in communicate(self, input, timeout)
#     924                 self._stdin_write(input)
#     925             elif self.stdout:
# --> 926                 stdout = self.stdout.read()
#     927                 self.stdout.close()
#     928             elif self.stderr:
#
# KeyboardInterrupt:

# %%
# Define the x domain
x = np.linspace( -1,1,num=41 )
# Define some necessary experimental features
exp_features = {
    "reset": {
        "isEnabled" : True,
        "qub_ampl": 5e-3,
        "cav_ampl": .200
    },
    "drag": {
        "isEnabled" : True,
        "drag_scaling": -523.19163e-12
    }
}

n_layers_range = [4,3]
functions_range = [relu, tanh]
cal_rate_range = [50,25,10,0]

for function in functions_range:
    if function == relu: 
        function_name = "relu"
    else:
        function_name = "tanh"

    for n_layers in n_layers_range:
        n_param = 3*n_layers - 1
        # Introduce initial parameters if wanted
        p = np.zeros(n_param)

        for cal_rate in cal_rate_range:
            # Create the Universal Approximant class
            univ_app = ua.UniversalApproximant( ua.EXPERIMENT, n_layers, exp_features )

            # Prepare Universal Approximant class
            univ_app.update_param(p)
            univ_app.define_range(x)
            univ_app.define_function(function)
            univ_app.define_cal_rate(cal_rate)

            time_start = t.perf_counter()

            print("                 ")
            print("                 ")
            print("                 ")
            print("For function: ", function_name)
            print("For number of layers: ", n_layers)
            print("For cal_rate: ", cal_rate)
            print("                 ")

            # Mimimize!
            results = minimize(univ_app.chi_square, p, method='Powell', options={"disp": True})

            time_elapsed = (t.perf_counter() - time_start)
            print("\"time\": ", time_elapsed,",")
            print("\"fun\": ", results.fun,",")
            print("\"message\": \"", results.message,"\",")
            print("\"nfev\": ", results.nfev,",")
            print("\"nit\":", results.nit,",")
            print("\"success\":", results.success,",")
            print("\"x\":", results.x)
# Out:
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  4
# For cal_rate:  50
#
# Optimization terminated successfully.
#          Current function value: 0.088119
#          Iterations: 4
#          Function evaluations: 611
# "time":  20676.7116866 ,
# "fun":  0.0881186791728204 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  611 ,
# "nit": 4 ,
# "success": True ,
# "x": [-6.46364292 12.88797094  4.5339699   8.45240493 -3.87734287 21.12366451
#  -4.24237883  0.08249963  8.70784662  1.05451579  7.87701054]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  4
# For cal_rate:  25
#
# Optimization terminated successfully.
#          Current function value: 0.089635
#          Iterations: 3
#          Function evaluations: 460
# "time":  17054.789352299995 ,
# "fun":  0.08963522958041113 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  460 ,
# "nit": 3 ,
# "success": True ,
# "x": [ 2.40717795  2.46966568  4.52888524  2.31973065  0.27047934  3.78608898
#   5.19988762  2.30319197 -0.75823484  2.21599986 -1.92061102]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  4
# For cal_rate:  10
#
# Optimization terminated successfully.
#          Current function value: 0.089470
#          Iterations: 2
#          Function evaluations: 283
# "time":  11437.6427329 ,
# "fun":  0.08947045671172822 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  283 ,
# "nit": 2 ,
# "success": True ,
# "x": [ 0.31593897 -2.63103757 -0.23635243 -1.54865961  0.19774635 -0.67228504
#  -2.85410197  0.84646269  4.64760534  2.60055771  2.72630371]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  4
# For cal_rate:  0
#
# Optimization terminated successfully.
#          Current function value: 0.085414
#          Iterations: 2
#          Function evaluations: 310
# "time":  12398.57701980001 ,
# "fun":  0.08541446918668372 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  310 ,
# "nit": 2 ,
# "success": True ,
# "x": [ 2.63808964e+00 -1.58992476e+00  4.45156220e+00 -3.59213613e-02
#  -6.04878384e-01 -6.47421408e-01  3.23606795e+00  5.27324519e-01
#   1.36196601e+00  1.09748976e-03 -1.15625692e+00]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  3
# For cal_rate:  50
#
# Optimization terminated successfully.
#          Current function value: 0.085280
#          Iterations: 1
#          Function evaluations: 103
# "time":  4274.225401100004 ,
# "fun":  0.085280436634534 ,
# "message": " Optimization terminated successfully. ",
# "nfev":  103 ,
# "nit": 1 ,
# "success": True ,
# "x": [ 0.85730788 -0.97871375  0.11145617 -0.59882958 15.94925133  2.12282115
#  -1.618034    0.88430471]
# Features checking still no supported. You should be doing well
#
#
#
# For function:  relu
# For number of layers:  3
# For cal_rate:  25
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# C:\Program Files\Labber\Script\Labber\_include37\_ScriptTools.pyc in performMeasurement(self, return_data)
#
# ~\AppData\Local\Programs\Python\Python37\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# ~\AppData\Local\Programs\Python\Python37\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['C:\\Program Files\\Labber\\Program\\Measurement.exe', '-i', 'c:\\Users\\Quantum\\Labber\\Scripts\\Universal Approximant\\Universal-Approximator\\algorithm.labber', '-o', 'c:\\Users\\Quantum\\Labber\\Scripts\\Universal Approximant\\Universal-Approximator\\res.hdf5', '-e', 'c:\\Users\\Quantum\\Labber\\Scripts\\Universal Approximant\\Universal-Approximator\\temp_data.txt']' returned non-zero exit status 3.
#
# During handling of the above exception, another exception occurred:
#
# MeasurementStoppedByUser                  Traceback (most recent call last)
# <ipython-input-6-91f17ec22c67> in <module>
#      50
#      51             # Mimimize!
# ---> 52             results = minimize(univ_app.chi_square, p, method='Powell', options={"disp": True})
#      53
#      54             time_elapsed = (t.perf_counter() - time_start)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     588         return _minimize_neldermead(fun, x0, args, callback, **options)
#     589     elif meth == 'powell':
# --> 590         return _minimize_powell(fun, x0, args, callback, **options)
#     591     elif meth == 'cg':
#     592         return _minimize_cg(fun, x0, args, jac, callback, **options)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in _minimize_powell(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    2610             fx2 = fval
#    2611             fval, x, direc1 = _linesearch_powell(func, x, direc1,
# -> 2612                                                  tol=xtol * 100)
#    2613             if (fx2 - fval) > delta:
#    2614                 delta = fx2 - fval
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in _linesearch_powell(func, p, xi, tol)
#    2396     def myfunc(alpha):
#    2397         return func(p + alpha*xi)
# -> 2398     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2399     xi = alpha_min*xi
#    2400     return squeeze(fret), p + xi, xi
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in brent(func, args, brack, tol, full_output, maxiter)
#    2107     options = {'xtol': tol,
#    2108                'maxiter': maxiter}
# -> 2109     res = _minimize_scalar_brent(func, brack, args, **options)
#    2110     if full_output:
#    2111         return res['x'], res['fun'], res['nit'], res['nfev']
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in _minimize_scalar_brent(func, brack, args, xtol, maxiter, **unknown_options)
#    2139                   full_output=True, maxiter=maxiter)
#    2140     brent.set_bracket(brack)
# -> 2141     brent.optimize()
#    2142     x, fval, nit, nfev = brent.get_result(full_output=True)
#    2143     return OptimizeResult(fun=fval, x=x, nit=nit, nfev=nfev,
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in optimize(self)
#    1990             else:
#    1991                 u = x + rat
# -> 1992             fu = func(*((u,) + self.args))      # calculate new output value
#    1993             funcalls += 1
#    1994
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in myfunc(alpha)
#    2395     """
#    2396     def myfunc(alpha):
# -> 2397         return func(p + alpha*xi)
#    2398     alpha_min, fret, iter, num = brent(myfunc, full_output=1, tol=tol)
#    2399     xi = alpha_min*xi
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# c:\Users\Quantum\Labber\Scripts\Universal Approximant\Universal-Approximator\scenario\universal_approximant.py in chi_square(self, p)
#     222         self.update_param(p)
#     223         P_1 = []
# --> 224         P_0 = self.run()
#     225         P_1 = [1 - x for x in P_0 ]
#     226         result = ( 0.5 / len(self.x) ) * np.sum( ( P_1 - self._fx )**2 )
#
# c:\Users\Quantum\Labber\Scripts\Universal Approximant\Universal-Approximator\scenario\universal_approximant.py in run(self)
#     158                 os.path.join( _RELPATH, "algorithm.labber"), # Here we should write the name parametrically
#     159                 os.path.join( _RELPATH, "res.hdf5" ) )
# --> 160         algorithm_raw = self.alg_meas.performMeasurement()
#     161         result = self._convert_result(algorithm_raw[1])
#     162         return result
#
# C:\Program Files\Labber\Script\Labber\_include37\_ScriptTools.pyc in performMeasurement(self, return_data)
#
# MeasurementStoppedByUser: b'Measurement was stopped by user.\r\n'
